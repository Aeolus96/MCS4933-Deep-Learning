# %% [markdown]
# # HW8.1: Segmented Skin Cancer Image Classification using DL models & techniques with Keras
# ---
# ###### Name: Devson Butani
# ###### ID: 000732711
# ###### LTU Honor Code: "I pledge that on all academic work that I submit, I will neither give nor receive unauthorized aid, nor will I present another person's work as my own."

# %% [markdown]
# # Get dataset from `Google Drive`

# %%
# # Mount Google Drive
# from google.colab import drive
# drive.mount('/content/drive')

# # Change directory to a drive folder of choice - Runs and models will be saved here
# %cd '/content/drive/MyDrive/DL_data'
# %pwd # Verify
# Out:
# '/Users/cedar/Downloads/HW8'

# %%
train_dir = "skin_cancer/train"
vali_dir = "skin_cancer/validation"
test_dir = "skin_cancer/test"

train_benign_dir = "skin_cancer/train/benign"
train_malignant_dir = "skin_cancer/train/malignant"
vali_benign_dir = "skin_cancer/validation/benign"
vali_malignant_dir = "skin_cancer/validation/malignant"
test_benign_dir = "skin_cancer/test/benign"
test_malignant_dir = "skin_cancer/test/malignant"

import os, shutil

print("total training benign images:", len(os.listdir(train_benign_dir)))
print("total training malignant images:", len(os.listdir(train_malignant_dir)))
print("total validation benign images:", len(os.listdir(vali_benign_dir)))
print("total validation malignant images:", len(os.listdir(vali_malignant_dir)))
print("total test benign images:", len(os.listdir(test_benign_dir)))
print("total test malignant images:", len(os.listdir(test_malignant_dir)))
# Out:
# total training benign images: 1000
# total training malignant images: 852
# total validation benign images: 300
# total validation malignant images: 218
# total test benign images: 140
# total test malignant images: 127

# %% [markdown]
# Dataset seems to be mostly balanced with a slight bias towards the benign class.

# %% [markdown]
# # Install Dependencies

# %%
# %pip install comet_ml --quiet
# %pip install pillow
# %pip install matplotlib

# %% [markdown]
# # Initialize `Comet` for datalogging

# %%
import comet_ml

comet_ml.config.save(api_key="mQStuXAxGmHmK1vOsTRucvz76")  # Insert API key from comet user account
comet_ml.init(project_name="HW8_Skin_Cancer_Classification")
# Out:
# COMET ERROR: '/Users/cedar/.comet.config' exists and force is not True; refusing to overwrite

# %% [markdown]
# # Import Dependencies

# %%
import numpy as np
from tensorflow import keras
import tensorflow as tf
from keras import layers
from keras import models
from keras import optimizers

# %%
# Check if GPU available and linked to tensorflow so that keras can use it
print("Num GPUs Available: ", len(tf.config.list_physical_devices("GPU")))
# Out:
# Num GPUs Available:  1

# %% [markdown]
# # Setup Data Generator and Augmentation

# %%
from keras.preprocessing.image import ImageDataGenerator

img_size = (150, 150)  # Need to investigate why 224x224 is lower accuracy. Maybe layer size?

train_datagen = ImageDataGenerator(
    rescale=1.0 / 255,  # Rescale the pixel values from [0-255] to [0, 1] for easier NN processing
    # rotation_range=15,  # Full range, samples may not be orientation normalized
    # width_shift_range=0.05,  # lateral shift
    # height_shift_range=0.05,  # vertical shift
    # shear_range=0.1, # Small because most samples are taken flat to surface. Does not improve performance
    # zoom_range=0.02,  # zoom can vary in real-life samples.
    horizontal_flip=True, # Try with or without. Without is better accuracy
    fill_mode="nearest",
)
# ^^^ DA improvement is less than 5% but helps curb overfitting for 10-15 more epochs
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=img_size,  # All images will be resized to 224x224
    batch_size=18,  # Use default batch size 32? 18 is better for the this Mac Pro's GPU
    shuffle=False,  # default is True
    class_mode="binary",
)  # Binary classification problem. Benign or malignant

vali_datagen = ImageDataGenerator(rescale=1.0 / 255)  # No DA
validation_generator = vali_datagen.flow_from_directory(
    vali_dir,
    target_size=img_size,
    batch_size=10,
    shuffle=False,
    class_mode="binary",
)

test_datagen = ImageDataGenerator(rescale=1.0 / 255)  # No DA
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=img_size,
    batch_size=267,  # a batch with all test images at once
    shuffle=False,
    class_mode="binary",
)
# Out:
# Found 1852 images belonging to 2 classes.
# Found 518 images belonging to 2 classes.
# Found 267 images belonging to 2 classes.

# %% [markdown]
# > After over 80 runs of varying models, DA features like shift, rotation and zoom did not help increase performance (OF at 30 epochs was pushed to 40 epochs). Turning everything but horizontal flip off, gave better results while minimizing overfitting (OF did not occur until 65-70 epochs).

# %% [markdown]
# # Build CNN

# %%
def build_model():
    model = models.Sequential()

    model.add(layers.DepthwiseConv2D((3, 3), activation="relu", input_shape=(150, 150, 3)))
    model.add(layers.DepthwiseConv2D((5, 5), activation="relu"))
    model.add(layers.DepthwiseConv2D((7, 7), activation="relu"))
    model.add(layers.MaxPooling2D((2, 2)))
    
    model.add(layers.Conv2D(9, (5, 5), activation="relu"))
    model.add(layers.SpatialDropout2D(0.2))
    model.add(layers.Conv2D(9, (9, 9), activation="relu"))
    model.add(layers.MaxPooling2D((2, 2)))
    
    model.add(layers.Conv2D(19, (9, 9), activation="relu"))
    model.add(layers.MaxPooling2D((3, 3)))
    model.add(layers.Flatten())  # CNN flattened
    
    model.add(layers.Dense(896, activation="relu"))  # DNN
    model.add(layers.Dropout(0.1))
    model.add(layers.Dense(147, activation="relu"))
    model.add(layers.Dense(1, activation="sigmoid"))

    model.compile(
        loss="binary_crossentropy",
        optimizer=optimizers.RMSprop(learning_rate=1e-4),
        metrics=["acc"],
    )
    return model

# %% [markdown]
# > Model uses Depth-wise Convulational layers to filter individual color channels in the beginning. This allowed for slightly better performance than just convolution layers. Given the skin cancer problem, identifying the dark regions of interest, this method may be a good choice.

# %%
# Start logging
experiment = comet_ml.Experiment(
    auto_histogram_weight_logging=True,
    # auto_histogram_gradient_logging=True,
    # auto_histogram_activation_logging=True,
)

# Start Training and Validation
model_DA = build_model()
model_DA.summary()
history = model_DA.fit(
    train_generator,
    steps_per_epoch=100,
    epochs=70,
    validation_data=validation_generator,
    validation_steps=50,
    verbose=2,
)
# Out:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Couldn't find a Git repository in '/Users/cedar/Downloads/HW8' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/aeolus96/hw8-skin-cancer-classification/240706943a314326b68b6fc8633a0d48
# Metal device set to: Apple M1 Pro
#
# systemMemory: 16.00 GB
# maxCacheSize: 5.33 GB
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  depthwise_conv2d (Depthwise  (None, 148, 148, 3)      30
#  Conv2D)
#
#  depthwise_conv2d_1 (Depthwi  (None, 144, 144, 3)      78
#  seConv2D)
#
#  depthwise_conv2d_2 (Depthwi  (None, 138, 138, 3)      150
#  seConv2D)
#
#  max_pooling2d (MaxPooling2D  (None, 69, 69, 3)        0
#  )
#
#  conv2d (Conv2D)             (None, 65, 65, 9)         684
#
#  spatial_dropout2d (SpatialD  (None, 65, 65, 9)        0
#  ropout2D)
#
#  conv2d_1 (Conv2D)           (None, 57, 57, 9)         6570
#
#  max_pooling2d_1 (MaxPooling  (None, 28, 28, 9)        0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 20, 20, 19)        13870
#
#  max_pooling2d_2 (MaxPooling  (None, 6, 6, 19)         0
#  2D)
#
#  flatten (Flatten)           (None, 684)               0
#
#  dense (Dense)               (None, 896)               613760
#
#  dropout (Dropout)           (None, 896)               0
#
#  dense_1 (Dense)             (None, 147)               131859
#
#  dense_2 (Dense)             (None, 1)                 148
#
# =================================================================
# Total params: 767,149
# Trainable params: 767,149
# Non-trainable params: 0
# _________________________________________________________________
# COMET INFO: Ignoring automatic log_parameter('verbose') because 'keras:verbose' is in COMET_LOGGING_PARAMETERS_IGNORE
# Epoch 1/70
# 2023-04-28 02:13:31.577443: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 100/100 - 5s - loss: 0.6941 - acc: 0.5050 - val_loss: 0.6916 - val_acc: 0.6000 - 5s/epoch - 51ms/step
# Epoch 2/70
# 100/100 - 3s - loss: 0.6934 - acc: 0.5462 - val_loss: 0.6887 - val_acc: 0.6000 - 3s/epoch - 35ms/step
# Epoch 3/70
# 100/100 - 3s - loss: 0.6910 - acc: 0.5145 - val_loss: 0.6767 - val_acc: 0.6000 - 3s/epoch - 33ms/step
# Epoch 4/70
# 100/100 - 3s - loss: 0.6958 - acc: 0.5362 - val_loss: 0.6747 - val_acc: 0.6000 - 3s/epoch - 33ms/step
# Epoch 5/70
# 100/100 - 3s - loss: 0.6951 - acc: 0.5261 - val_loss: 0.6758 - val_acc: 0.6000 - 3s/epoch - 34ms/step
# Epoch 6/70
# 100/100 - 3s - loss: 0.6964 - acc: 0.5261 - val_loss: 0.6793 - val_acc: 0.6000 - 3s/epoch - 34ms/step
# Epoch 7/70
# 100/100 - 3s - loss: 0.6895 - acc: 0.5562 - val_loss: 0.6840 - val_acc: 0.6040 - 3s/epoch - 34ms/step
# Epoch 8/70
# 100/100 - 3s - loss: 0.6897 - acc: 0.5400 - val_loss: 0.6666 - val_acc: 0.6000 - 3s/epoch - 34ms/step
# Epoch 9/70
# 100/100 - 3s - loss: 0.6929 - acc: 0.5362 - val_loss: 0.6778 - val_acc: 0.6040 - 3s/epoch - 34ms/step
# Epoch 10/70
# 100/100 - 3s - loss: 0.6919 - acc: 0.5250 - val_loss: 0.6800 - val_acc: 0.6160 - 3s/epoch - 34ms/step
# Epoch 11/70
# 100/100 - 3s - loss: 0.6888 - acc: 0.5306 - val_loss: 0.6643 - val_acc: 0.6040 - 3s/epoch - 34ms/step
# Epoch 12/70
# 100/100 - 3s - loss: 0.6878 - acc: 0.5539 - val_loss: 0.6782 - val_acc: 0.6900 - 3s/epoch - 34ms/step
# Epoch 13/70
# 100/100 - 3s - loss: 0.6861 - acc: 0.5501 - val_loss: 0.6544 - val_acc: 0.6200 - 3s/epoch - 34ms/step
# Epoch 14/70
# 100/100 - 4s - loss: 0.6779 - acc: 0.5590 - val_loss: 0.6479 - val_acc: 0.6040 - 4s/epoch - 35ms/step
# Epoch 15/70
# 100/100 - 3s - loss: 0.6824 - acc: 0.5628 - val_loss: 0.6311 - val_acc: 0.6180 - 3s/epoch - 34ms/step
# Epoch 16/70
# 100/100 - 3s - loss: 0.6773 - acc: 0.5756 - val_loss: 0.6341 - val_acc: 0.6660 - 3s/epoch - 34ms/step
# Epoch 17/70
# 100/100 - 3s - loss: 0.6765 - acc: 0.5806 - val_loss: 0.6541 - val_acc: 0.6680 - 3s/epoch - 34ms/step
# Epoch 18/70
# 100/100 - 3s - loss: 0.6723 - acc: 0.5929 - val_loss: 0.6379 - val_acc: 0.6820 - 3s/epoch - 35ms/step
# Epoch 19/70
# 100/100 - 3s - loss: 0.6526 - acc: 0.6089 - val_loss: 0.6973 - val_acc: 0.5220 - 3s/epoch - 34ms/step
# Epoch 20/70
# 100/100 - 3s - loss: 0.6459 - acc: 0.6340 - val_loss: 0.6705 - val_acc: 0.6140 - 3s/epoch - 34ms/step
# Epoch 21/70
# 100/100 - 3s - loss: 0.6512 - acc: 0.6174 - val_loss: 0.5941 - val_acc: 0.7080 - 3s/epoch - 35ms/step
# Epoch 22/70
# 100/100 - 3s - loss: 0.6348 - acc: 0.6374 - val_loss: 0.6664 - val_acc: 0.6100 - 3s/epoch - 34ms/step
# Epoch 23/70
# 100/100 - 4s - loss: 0.6491 - acc: 0.6174 - val_loss: 0.5819 - val_acc: 0.6680 - 4s/epoch - 36ms/step
# Epoch 24/70
# 100/100 - 3s - loss: 0.6354 - acc: 0.6400 - val_loss: 0.5725 - val_acc: 0.7000 - 3s/epoch - 34ms/step
# Epoch 25/70
# 100/100 - 3s - loss: 0.6140 - acc: 0.6535 - val_loss: 0.6920 - val_acc: 0.5800 - 3s/epoch - 34ms/step
# Epoch 26/70
# 100/100 - 3s - loss: 0.6249 - acc: 0.6591 - val_loss: 0.5634 - val_acc: 0.6960 - 3s/epoch - 33ms/step
# Epoch 27/70
# 100/100 - 3s - loss: 0.6352 - acc: 0.6479 - val_loss: 0.5646 - val_acc: 0.6960 - 3s/epoch - 33ms/step
# Epoch 28/70
# 100/100 - 3s - loss: 0.5980 - acc: 0.6852 - val_loss: 0.5574 - val_acc: 0.6920 - 3s/epoch - 33ms/step
# Epoch 29/70
# 100/100 - 3s - loss: 0.6045 - acc: 0.6719 - val_loss: 0.5950 - val_acc: 0.7040 - 3s/epoch - 34ms/step
# Epoch 30/70
# 100/100 - 3s - loss: 0.6042 - acc: 0.6741 - val_loss: 0.5715 - val_acc: 0.7340 - 3s/epoch - 34ms/step
# Epoch 31/70
# 100/100 - 3s - loss: 0.5977 - acc: 0.6802 - val_loss: 0.5810 - val_acc: 0.6780 - 3s/epoch - 33ms/step
# Epoch 32/70
# 100/100 - 3s - loss: 0.6082 - acc: 0.6724 - val_loss: 0.5687 - val_acc: 0.6900 - 3s/epoch - 33ms/step
# Epoch 33/70
# 100/100 - 3s - loss: 0.6035 - acc: 0.6735 - val_loss: 0.5488 - val_acc: 0.7060 - 3s/epoch - 34ms/step
# Epoch 34/70
# 100/100 - 3s - loss: 0.5847 - acc: 0.6841 - val_loss: 0.5475 - val_acc: 0.6940 - 3s/epoch - 34ms/step
# Epoch 35/70
# 100/100 - 3s - loss: 0.5796 - acc: 0.6980 - val_loss: 0.5898 - val_acc: 0.6860 - 3s/epoch - 33ms/step
# Epoch 36/70
# 100/100 - 4s - loss: 0.5875 - acc: 0.6897 - val_loss: 0.6816 - val_acc: 0.6440 - 4s/epoch - 36ms/step
# Epoch 37/70
# 100/100 - 3s - loss: 0.5956 - acc: 0.6897 - val_loss: 0.5544 - val_acc: 0.6940 - 3s/epoch - 34ms/step
# Epoch 38/70
# 100/100 - 4s - loss: 0.5938 - acc: 0.6796 - val_loss: 0.5724 - val_acc: 0.7220 - 4s/epoch - 35ms/step
# Epoch 39/70
# 100/100 - 3s - loss: 0.5936 - acc: 0.6852 - val_loss: 0.5403 - val_acc: 0.7280 - 3s/epoch - 35ms/step
# Epoch 40/70
# 100/100 - 3s - loss: 0.5922 - acc: 0.6969 - val_loss: 0.5398 - val_acc: 0.7300 - 3s/epoch - 35ms/step
# Epoch 41/70
# 100/100 - 4s - loss: 0.5762 - acc: 0.6930 - val_loss: 0.5446 - val_acc: 0.7020 - 4s/epoch - 35ms/step
# Epoch 42/70
# 100/100 - 3s - loss: 0.5805 - acc: 0.7019 - val_loss: 0.5362 - val_acc: 0.7300 - 3s/epoch - 34ms/step
# Epoch 43/70
# 100/100 - 3s - loss: 0.5590 - acc: 0.7202 - val_loss: 0.5738 - val_acc: 0.7020 - 3s/epoch - 34ms/step
# Epoch 44/70
# 100/100 - 3s - loss: 0.5759 - acc: 0.6986 - val_loss: 0.5325 - val_acc: 0.7180 - 3s/epoch - 35ms/step
# Epoch 45/70
# 100/100 - 3s - loss: 0.5650 - acc: 0.7030 - val_loss: 0.5934 - val_acc: 0.6840 - 3s/epoch - 34ms/step
# Epoch 46/70
# 100/100 - 3s - loss: 0.5695 - acc: 0.7075 - val_loss: 0.6304 - val_acc: 0.6700 - 3s/epoch - 34ms/step
# Epoch 47/70
# 100/100 - 3s - loss: 0.5797 - acc: 0.6997 - val_loss: 0.5394 - val_acc: 0.7060 - 3s/epoch - 35ms/step
# Epoch 48/70
# 100/100 - 3s - loss: 0.5596 - acc: 0.7119 - val_loss: 0.5263 - val_acc: 0.7340 - 3s/epoch - 34ms/step
# Epoch 49/70
# 100/100 - 3s - loss: 0.5555 - acc: 0.7119 - val_loss: 0.5261 - val_acc: 0.7480 - 3s/epoch - 34ms/step
# Epoch 50/70
# 100/100 - 4s - loss: 0.5580 - acc: 0.7136 - val_loss: 0.7001 - val_acc: 0.6500 - 4s/epoch - 36ms/step
# Epoch 51/70
# 100/100 - 4s - loss: 0.5688 - acc: 0.7161 - val_loss: 0.5296 - val_acc: 0.7200 - 4s/epoch - 36ms/step
# Epoch 52/70
# 100/100 - 3s - loss: 0.5551 - acc: 0.7113 - val_loss: 0.5454 - val_acc: 0.7000 - 3s/epoch - 34ms/step
# Epoch 53/70
# 100/100 - 3s - loss: 0.5629 - acc: 0.7147 - val_loss: 0.5343 - val_acc: 0.7220 - 3s/epoch - 34ms/step
# Epoch 54/70
# 100/100 - 3s - loss: 0.5430 - acc: 0.7336 - val_loss: 0.5237 - val_acc: 0.7420 - 3s/epoch - 34ms/step
# Epoch 55/70
# 100/100 - 3s - loss: 0.5502 - acc: 0.7225 - val_loss: 0.5219 - val_acc: 0.7500 - 3s/epoch - 34ms/step
# Epoch 56/70
# 100/100 - 3s - loss: 0.5541 - acc: 0.7291 - val_loss: 0.5479 - val_acc: 0.7220 - 3s/epoch - 33ms/step
# Epoch 57/70
# 100/100 - 3s - loss: 0.5487 - acc: 0.7247 - val_loss: 0.6482 - val_acc: 0.6760 - 3s/epoch - 34ms/step
# Epoch 58/70
# 100/100 - 3s - loss: 0.5640 - acc: 0.7058 - val_loss: 0.5195 - val_acc: 0.7400 - 3s/epoch - 33ms/step
# Epoch 59/70
# 100/100 - 3s - loss: 0.5349 - acc: 0.7236 - val_loss: 0.5380 - val_acc: 0.7220 - 3s/epoch - 33ms/step
# Epoch 60/70
# 100/100 - 4s - loss: 0.5521 - acc: 0.7128 - val_loss: 0.5086 - val_acc: 0.7600 - 4s/epoch - 36ms/step
# Epoch 61/70
# 100/100 - 4s - loss: 0.5427 - acc: 0.7241 - val_loss: 0.5310 - val_acc: 0.7320 - 4s/epoch - 35ms/step
# Epoch 62/70
# 100/100 - 3s - loss: 0.5532 - acc: 0.7175 - val_loss: 0.5076 - val_acc: 0.7500 - 3s/epoch - 34ms/step
# Epoch 63/70
# 100/100 - 3s - loss: 0.5362 - acc: 0.7347 - val_loss: 0.5341 - val_acc: 0.7300 - 3s/epoch - 34ms/step
# Epoch 64/70
# 100/100 - 3s - loss: 0.5400 - acc: 0.7369 - val_loss: 0.5281 - val_acc: 0.7300 - 3s/epoch - 34ms/step
# Epoch 65/70
# 100/100 - 3s - loss: 0.5330 - acc: 0.7314 - val_loss: 0.5394 - val_acc: 0.7140 - 3s/epoch - 34ms/step
# Epoch 66/70
# 100/100 - 3s - loss: 0.5526 - acc: 0.7186 - val_loss: 0.5032 - val_acc: 0.7580 - 3s/epoch - 35ms/step
# Epoch 67/70
# 100/100 - 3s - loss: 0.5357 - acc: 0.7347 - val_loss: 0.5265 - val_acc: 0.7340 - 3s/epoch - 34ms/step
# Epoch 68/70
# 100/100 - 4s - loss: 0.5359 - acc: 0.7330 - val_loss: 0.5057 - val_acc: 0.7460 - 4s/epoch - 36ms/step
# Epoch 69/70
# 100/100 - 3s - loss: 0.5282 - acc: 0.7458 - val_loss: 0.4985 - val_acc: 0.7640 - 3s/epoch - 34ms/step
# Epoch 70/70
# 100/100 - 3s - loss: 0.5222 - acc: 0.7508 - val_loss: 0.4996 - val_acc: 0.7580 - 3s/epoch - 34ms/step

# %%
import matplotlib.pyplot as plt

acc2 = history.history["acc"]
val_acc2 = history.history["val_acc"]
loss2 = history.history["loss"]
val_loss2 = history.history["val_loss"]

epochs = range(len(acc2))

plt.plot(epochs, acc2, "b", label="Training acc")
plt.plot(epochs, val_acc2, "r", label="Validation acc")
plt.title("Training and validation accuracy")
plt.legend()

plt.figure()

plt.plot(epochs, loss2, "b", label="Training loss")
plt.plot(epochs, val_loss2, "r", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()

plt.show()

# %%
import os.path

path, dirs, files = next(os.walk("/Users/cedar/Downloads/HW8/history_files"))
file_count = len(files)
save_path = "history_files/"
name_of_file = "model_"
completeName = os.path.join(save_path, name_of_file + str(file_count) + ".h5")
# model_DA.save('history_files/skin_cancer_03.h5')
print(completeName)
model_DA.save(completeName)
# Out:
# history_files/model_21.h5

# %%
# Run the test dataset to find the accuracy
test_loss, test_acc = model_DA.evaluate(test_generator, steps=1)  # generator will get both data and label
print(f"test acc: {test_acc*100.0:.2f}%")
# Out:
# 1/1 [==============================] - 0s 297ms/step - loss: 0.4922 - acc: 0.7678
# test acc: 76.78%

# %%
# Plot the results, actual v/s model confidence
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 6))
images = test_generator[0][0]
labels = test_generator[0][1]
results = model_DA.predict(test_generator)
for i in range(12):
    plt.subplot(4, 3, i + 1)
    i = i + 134  # offset for un-shuffled dataset
    plt.tight_layout()
    plt.imshow(images[i])
    actual = int(labels[i])
    predicted = results[i][0]
    predicted = round(float(predicted), 3)
    title = f"{actual}::{predicted}"
    if actual - predicted < -0.5:  # false positive or false negative
        title = f"{actual}::{predicted}::F+ve"
    if actual - predicted > 0.5:
        title = f"{actual}::{predicted}::F-ve"
    plt.title(title)
    plt.xticks([])
    plt.yticks([])
# Out:
# 1/1 [==============================] - 0s 249ms/step

# %% [markdown]
# > Predictions ran on the middle of the test dataset show the results and if there are false positives or false negatives.
#
# > Since the data is small and slightly biased towards benign images, the results show small bias towards them.
#
# > If the images were pre-processed with gaussian blur instead of black background, the results may be better. The useful pixel area in the image is only around 10% which can be a significant contributor to the overall accuracy.
#
# > Cropping the useful sections and upscaling them may result in better accuracy for this scenario.

# %%
experiment.end()  # CometML stop logging
# Out:
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.com/aeolus96/hw8-skin-cancer-classification/240706943a314326b68b6fc8633a0d48
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     acc [70]                  : (0.5050055384635925, 0.7508342862129211)
# COMET INFO:     batch_acc [700]           : (0.0, 1.0)
# COMET INFO:     batch_loss [700]          : (0.1624426543712616, 1.4173253774642944)
# COMET INFO:     epoch_duration [70]       : (3.2447274579972145, 5.131551332997333)
# COMET INFO:     loss [70]                 : (0.5222101807594299, 0.6963916420936584)
# COMET INFO:     val_acc [70]              : (0.5220000147819519, 0.7639999985694885)
# COMET INFO:     val_loss [70]             : (0.4985140264034271, 0.7000732421875)
# COMET INFO:     validate_batch_acc [350]  : (0.10000000149011612, 1.0)
# COMET INFO:     validate_batch_loss [350] : (0.13383349776268005, 0.9869431257247925)
# COMET INFO:   Others:
# COMET INFO:     trainable_params : 767149
# COMET INFO:   Parameters:
# COMET INFO:     RMSprop_centered      : False
# COMET INFO:     RMSprop_decay         : 0.0
# COMET INFO:     RMSprop_epsilon       : 1e-07
# COMET INFO:     RMSprop_learning_rate : 0.0001
# COMET INFO:     RMSprop_momentum      : 0.0
# COMET INFO:     RMSprop_name          : RMSprop
# COMET INFO:     RMSprop_rho           : 0.9
# COMET INFO:     epochs                : 70
# COMET INFO:     steps                 : 100
# COMET INFO:   Uploads:
# COMET INFO:     conda-environment-definition : 1
# COMET INFO:     conda-info                   : 1
# COMET INFO:     conda-specification          : 1
# COMET INFO:     environment details          : 1
# COMET INFO:     filename                     : 1
# COMET INFO:     histogram3d                  : 1278
# COMET INFO:     installed packages           : 1
# COMET INFO:     model graph                  : 1
# COMET INFO:     notebook                     : 1
# COMET INFO:     source_code                  : 1
# COMET INFO:
# COMET INFO: Please wait for metadata to finish uploading (timeout is 3600 seconds)
